# %%
import pandas as pd
dadosUm = pd.read_csv('dados_1.csv')
dadosUm
# Out:
#      Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0    -1.918589  -2.504736   0.129979   1.144094   1.714314   0.644021
# 1     1.703727   1.236490   2.632384  -0.451056  -1.318009   0.158059
# 2     0.513048  -4.473221   1.972778   4.994542  -0.839594  -1.320484
# 3    -0.295201  -5.930419   0.122670   0.290137  -5.200017   5.789733
# 4     0.587042   2.795540   2.277552  -1.600965   1.504304   1.756499
# ..         ...        ...        ...        ...        ...        ...
# 995   2.171993  -1.011907   2.757667  -0.652046   0.773601   3.054215
# 996  -0.315192  -1.750600  -1.477538   0.126380   1.546491  -0.301514
# 997  -1.180498  -1.584507  -0.163904   2.515817   1.865299  -4.498530
# 998   0.120373  -2.374496  -1.550744   2.629338  -1.719848  -1.457165
# 999   0.334300   0.431714   1.240776   0.368752  -0.739443   2.626357
#
#      Feature_6  Feature_7  Feature_8  Feature_9  ...  Feature_11  Feature_12  \
# ...

# %%
dadosDois = pd.read_csv('dados_2.csv',sep=';')
dadosDois
# Out:
#      Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0    -0.137864   1.532235   2.196646   0.729666   0.767479  -1.226179
# 1    -1.579388   2.229179   0.227496   0.227534   0.635968   1.609521
# 2    -0.177830   0.940990   0.585904  -1.391726  -0.736770  -1.406815
# 3    -0.391865   1.320738   2.015275  -1.018709   1.290644  -1.889649
# 4     0.716359   0.533305   1.483744  -2.165546  -0.734811  -0.640154
# ..         ...        ...        ...        ...        ...        ...
# 995  -0.849169   1.073884  -0.385673  -0.113270   0.434503  -1.334611
# 996  -1.005058   1.234090  -0.459657   0.158606  -1.079842   0.918915
# 997  -0.700731   1.491741   0.472630   0.180478  -1.366858   0.018017
# 998  -0.483023   0.827078  -0.671721   0.101566  -1.254161  -0.276889
# 999  -0.469247   1.185412  -1.672894  -0.548944   0.404213  -0.249072
#
#      Feature_6  Feature_7  Feature_8  Feature_9  Label
# 0    -1.560715   0.681743   0.979455   0.962503      0
# ...

# %%
dadosTres = pd.read_csv('dados_3.csv', sep=' ')
dadosTres
# Out:
#       Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Label
# 0      1.901371   0.858262   1.584843   1.130733  -1.522889      1
# 1      0.600063   0.225434   0.520463  -0.074065  -0.255904      1
# 2     -1.832360   2.199767  -1.689085   2.345099  -0.323531      1
# 3     -1.839614   0.741564  -1.688487   2.199702  -0.244150      1
# 4     -0.939304   0.110936  -0.857044   1.014978  -0.068246      0
# ...         ...        ...        ...        ...        ...    ...
# 2995  -0.759921   1.353863  -0.615804  -0.825844   0.803644      0
# 2996  -1.187728  -0.066599  -1.088481   1.384687  -0.139106      1
# 2997   1.539066   0.850768   1.316687   0.196862  -0.858073      0
# 2998   1.552319   0.177792   1.266162   1.512109  -1.550442      1
# 2999  -1.051356   1.699054  -0.899607  -0.131039   0.584367      0
#
# [3000 rows x 6 columns]

# %%
dadosQuatro = pd.read_csv('dados_4.csv', sep='\t', header =None)
dadosQuatro
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.848905 -2.192934 -1.043920 -1.010977  0.049679  1.032537 -0.122524
# 1   -0.919321  1.456459  0.147485 -3.275885 -0.333815  1.000514  0.004069
# 2   -1.295318  0.411843 -1.159148 -2.495045 -1.221641  0.369156 -1.533276
# 3   -0.186614 -0.384290  0.441852 -0.139822 -0.581831  0.628671 -0.786553
# 4    0.133624 -0.700827 -0.605545 -1.746508 -0.515908  0.001855  0.426752
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -1.278002  0.042174 -1.043923 -0.582927  2.087794 -0.382436 -2.192232
# 996  0.179333 -1.337413  1.824631  0.303217 -0.185231  1.024515  0.264696
# 997 -0.625184 -0.823048  0.765353  2.195479 -0.746329 -1.012400  0.496052
# 998 -1.026824 -1.730290  0.849879  1.500112 -0.309153  0.737387 -0.409057
# 999  0.856985 -1.018874 -1.397558 -0.140379 -0.448334 -2.353416  1.344879
#
#            7         8         9   10
# 0    2.443615 -0.301006 -0.814983   3
# ...

# %%
dadosCinco = pd.read_csv('dados_5.csv', sep='\t')
dadosCinco
# Out:
#      Unnamed: 0  Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  \
# 0             0  -0.021182   0.012130  -0.018755  -0.063668  -0.037392
# 1             1   0.000074   0.019679   0.037544  -0.047496  -0.000815
# 2             2  -0.045825  -0.033578  -0.007455   0.023250  -0.014264
# 3             3   0.026060  -0.004648   0.009928  -0.026802   0.026844
# 4             4  -0.036686  -0.026732  -0.005009   0.011530   0.003022
# ..          ...        ...        ...        ...        ...        ...
# 995         995   0.009579  -0.008893  -0.015631   0.036372  -0.002781
# 996         996  -0.033153  -0.050921   0.008092   0.036656  -0.010303
# 997         997  -0.056353  -0.046244   0.016512  -0.005966   0.043043
# 998         998  -0.032132  -0.063062   0.008611  -0.026438  -0.015834
# 999         999  -0.026083   0.000652  -0.005897  -0.021854  -0.010879
#
#      Feature_5  Feature_6  Feature_7  Feature_8  Feature_9    Target
# ...

# %%
dadosSeis = pd.read_csv('dados_6.csv', header=None, sep='\t')
dadosSeis
# Out:
#               0         1         2         3         4         5         6   \
# 0      -1.626850 -2.675881  3.029605 -0.323830  0.190790 -2.559812  0.406867
# 1       0.124887 -1.025044  0.521990 -2.095166  0.221847 -1.693476 -0.426833
# 2      -0.541229 -2.368121  1.827388 -1.370912  1.680010 -2.452930  0.490978
# 3      -4.046177  4.052463  3.835139 -0.558254 -0.859638  1.935893  0.892909
# 4      -2.791270  1.776555  2.142707  0.279566  1.242548  1.178050 -0.258540
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  1.841844 -1.081227 -0.601514 -1.041679 -1.380062 -0.929006 -0.597511
# 999996 -2.805988  1.737186  1.404542  1.806035 -0.436407  1.975983 -0.535935
# 999997 -3.909082  1.589143  0.114744  4.023767  1.252311  3.577290 -1.188318
# 999998 -2.581747  2.413372  2.464464  0.606348  0.679737  1.412132  0.311622
# 999999 -0.054737 -1.125135  1.175885 -2.431503 -0.981067 -2.161906 -0.021619
#
#               7         8         9   10
# ...

# %%
dadosSete = pd.read_csv('dados_7.csv', encoding='latin', sep=';').dropna()
dadosSete
# Out:
#                      Feature_0                Feature_1  \
# 0         -364.202.786.094.168      -0.8564950098531674
# 1       -3.069.515.464.093.610       0.3905100998188409
# 2       -1.095.382.246.835.630      -0.2895228605137005
# 3          -0.6849995114017773       0.4060420930014336
# 4      -14.687.019.920.326.700  -19.087.925.015.033.300
# ...                        ...                      ...
# 99995   12.028.459.078.127.000   24.939.360.588.759.000
# 99996  -34.365.771.929.166.200      0.15634794953697181
# 99997  -14.802.665.936.976.500     -0.09347362555293345
# 99998  -16.208.269.928.613.100      -0.6924131629386829
# 99999  -20.578.372.016.681.400      -0.7100442192408113
#
#                      Feature_2                Feature_3  \
# 0          0.48003085515073796  -30.389.964.131.652.900
# 1      -15.308.593.764.090.500  -34.391.907.840.140.100
# 2          -0.7505425213388771    3.020.338.664.949.950
# 3           0.7559655696373988       0.9619779562839578
# ...

# %%
dadosOito = pd.read_csv('dados_8.csv', sep=';').dropna()
dadosOito
# Out:
#       Feature_0            Feature_1  Feature_2 Label
# 0      0.036435    1.192022418861353  -1.326348     0
# 1     -2.362614    0.999835110803413  -0.969421     0
# 2     -0.439421   0.4202877067824724   1.409511     1
# 3     -1.760930  -0.7317809156657651  -0.925953     0
# 4     -0.216907   1.3998695375029746   2.076070     1
# ...         ...                  ...        ...   ...
# 4995  -0.393958  -1.7838043938979733   0.153619     1
# 4996  -1.720548  -0.6341833261618026  -1.121617     0
# 4997  -0.287575   0.9354108121251281  -0.804564     0
# 4998   0.978160   1.0806602274484232   0.947937     1
# 4999   0.228668   0.9039355800442616  -0.838433     0
#
# [3999 rows x 4 columns]

# %% [markdown]
# ### Aula Seis - 6

# %%
dadosNove = pd.read_csv('dados_9.csv', sep=';', decimal=',', na_values={'Feature_2':'-999'})
dadosNove.describe()
# Out:
#          Feature_0    Feature_1    Feature_2
# count  9499.000000  9499.000000  9499.000000
# mean     -0.139551     0.151968    -0.286849
# std       1.022564     1.015530     1.046226
# min      -3.440038    -4.616532    -5.364879
# 25%      -0.804302    -0.490999    -0.962548
# 50%      -0.369344     0.210618    -0.394128
# 75%       0.292228     0.859137     0.273881
# max       5.899292     4.288203     4.477169

# %%
dadosNove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10500 entries, 0 to 10499
# Data columns (total 4 columns):
# Feature_0    9499 non-null float64
# Feature_1    9499 non-null float64
# Feature_2    9499 non-null float64
# Label        3 non-null object
# dtypes: float64(3), object(1)
# memory usage: 328.2+ KB

# %%
dadosNove.loc[dadosNove['Label'].notna()]
# Out:
#       Feature_0  Feature_1  Feature_2  Label
# 0     -0.452605  -0.022775  -0.091485   alto
# 6252   1.046313  -1.159016   1.049090  baixo
# 8988  -0.048281  -1.354528  -1.757549  medio

# %%
novoDadosNove = dadosNove.copy()
novoDadosNove['Label'] = dadosNove['Label'].fillna(method='ffill')
novoDadosNove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10500 entries, 0 to 10499
# Data columns (total 4 columns):
# Feature_0    9499 non-null float64
# Feature_1    9499 non-null float64
# Feature_2    9499 non-null float64
# Label        10500 non-null object
# dtypes: float64(3), object(1)
# memory usage: 328.2+ KB

# %%
novoDadosNove.isna().sum()/novoDadosNove.shape[0]
# Out:
# Feature_0    0.095333
# Feature_1    0.095333
# Feature_2    0.095333
# Label        0.000000
# dtype: float64

# %%
novoDadosNove[novoDadosNove['Feature_0'].isna()]
# Out:
#        Feature_0  Feature_1  Feature_2  Label
# 1040         NaN        NaN        NaN   alto
# 1041         NaN        NaN        NaN   alto
# 1042         NaN        NaN        NaN   alto
# 1045         NaN        NaN        NaN   alto
# 1046         NaN        NaN        NaN   alto
# ...          ...        ...        ...    ...
# 10483        NaN        NaN        NaN  medio
# 10487        NaN        NaN        NaN  medio
# 10490        NaN        NaN        NaN  medio
# 10492        NaN        NaN        NaN  medio
# 10498        NaN        NaN        NaN  medio
#
# [1001 rows x 4 columns]

# %%
novoDadosNove = novoDadosNove.dropna()
novoDadosNove
# Out:
#        Feature_0  Feature_1  Feature_2  Label
# 0      -0.452605  -0.022775  -0.091485   alto
# 1       0.217810  -1.666798   0.467025   alto
# 2      -0.680914  -0.905353   0.873003   alto
# 3      -0.151409   0.086429  -0.390574   alto
# 4      -0.056500   0.717154  -1.556635   alto
# ...          ...        ...        ...    ...
# 10494   0.264197  -1.990286   1.541298  medio
# 10495   1.240600   0.429632  -0.046192  medio
# 10496   0.686432  -2.463771   0.292171  medio
# 10497   1.413050  -0.322188   0.656235  medio
# 10499   1.703322  -0.429376   1.001266  medio
#
# [9499 rows x 4 columns]

# %%
novoDadosNove.duplicated().sum()
novoDadosNove['Label'].map({'alto': 2})
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 10494    NaN
# 10495    NaN
# 10496    NaN
# 10497    NaN
# 10499    NaN
# Name: Label, Length: 9499, dtype: float64

# %% [markdown]
# ### Teste para Clasificação

# %%
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
novoDadosNove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9499 entries, 0 to 10499
# Data columns (total 4 columns):
# Feature_0    9499 non-null float64
# Feature_1    9499 non-null float64
# Feature_2    9499 non-null float64
# Label        9499 non-null object
# dtypes: float64(3), object(1)
# memory usage: 371.1+ KB

# %%
novoDadosNove.head()
# Out:
#    Feature_0  Feature_1  Feature_2 Label
# 0  -0.452605  -0.022775  -0.091485  alto
# 1   0.217810  -1.666798   0.467025  alto
# 2  -0.680914  -0.905353   0.873003  alto
# 3  -0.151409   0.086429  -0.390574  alto
# 4  -0.056500   0.717154  -1.556635  alto

# %%
#split entre features e label
X = novoDadosNove.drop(columns= ['Label'])
y = novoDadosNove.loc[:, 'Label']

# %%
# Split entre dados de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# treinando o modelo
modelo = DecisionTreeClassifier(random_state=42)
modelo.fit(X_train, y_train)

y_pred = modelo.predict(X_test)

# %%
# avaliando o modelo
acc_modelo = accuracy_score(y_test, y_pred) * 100
print(f'acurácia: {acc_modelo:.2f}%')
# Out:
# acurácia: 79.65%
#           0
# 0     baixo
# 1     baixo
# 2      alto
# 3     baixo
# 4     baixo
# ...     ...
# 2845   alto
# 2846  medio
# 2847   alto
# 2848  baixo
# 2849  medio
#
# [2850 rows x 1 columns]
